# %% [markdown]
# # ENZYMES contraction coefficient changes

# %%
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy

coefficientsSecond=[0.2,0.4,0.6,0.8,0.9]
coefficientsFirst=[512]
dataset="ENZYMES"

file_constraited="ENZYMESConvergence/TrainConvergence"
save_png_name='ContractionCoefficientsCompare_{}.png'.format(dataset)
start_plot=30
epochs=70
args=coefficientsSecond
PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     116     try:
# --> 117         num = operator.index(num)
#     118     except TypeError:
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-5052f5d79969> in <module>
#      10 epochs=70
#      11 args=coefficientsSecond
# ---> 12 PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
#
# /git/GNN/pytorch_geometric-1/PlotMonteCalorsConvergence.py in PlotMonteCalorsTimesConvergenceNpy(dataset, modelName, file_constraited, coefficientsFirst, coefficientsSecond, coefficientsThree, coefficientsFour, save_png_name, start_plot, epochs, *args)
#      12                                        coefficientsSecond,coefficientsThree,coefficientsFour,save_png_name,start_plot,epochs,*args):
#      13     Legend=args
# ---> 14     x=np.linspace(start_plot,start_plot+epochs-1,num=epochs).tolist()
#      15     if len(coefficientsFirst)>1:
#      16         coefficients=coefficientsFirst
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# /opt/conda/lib/python3.6/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     119         raise TypeError(
#     120             "object of type {} cannot be safely interpreted as an integer."
# --> 121                 .format(type(num)))
#     122
#     123     if num < 0:
#
# TypeError: object of type <class 'float'> cannot be safely interpreted as an integer.

# %% [markdown]
# # ENZYMES batch size changes

# %% [markdown]
# # Cora Batch size change

# %%
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy
coefficientsFirst=[16,32,64,128] #
coefficientsSecond=[0.6]
dataset="Cora"
file_constraited="CoraConvergence/TrainConvergence"
save_png_name='BatchSizeChangesCompare_{}.png'.format(dataset)
start_plot=30
epochs=70
args=coefficientsFirst
PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-0db96bc391ee> in <module>
#       8 epochs=70
#       9 args=coefficientsFirst
# ---> 10 PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
#
# /git/GNN/pytorch_geometric-1/PlotMonteCalorsConvergence.py in PlotMonteCalorsTimesConvergenceNpy(dataset, modelName, file_constraited, coefficientsFirst, coefficientsSecond, coefficientsThree, coefficientsFour, save_png_name, start_plot, epochs, *args)
#      44         for i in range(len(coefficients)):
#      45             TrainConvergenceAll=[]
# ---> 46             for file in glob.glob("{}*{}*{}*{}*{}*{}*{}*.npy".format(file_constraited,dataset,modelName,coefficientsFirst[0],coefficientsSecond[i],coefficientsThree[0],coefficientsFour[0])):
#      47                 print(file)
#      48                 TrainConvergence=np.load(file).tolist()
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# # Cora  contraction coefficient changes

# %%
coefficientsFirst=[1, 2, 3, 4, 5, 6]
coefficientsSecond=[0.5]

dataset="Cora"
file_constraited="TrainConvergence"
save_png_name='LayerNumCompare_{}.png'.format(dataset)
start_plot=0
epochs=200
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy
args=coefficientsFirst
PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-6436c4d5ec19> in <module>
#       8 from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy
#       9 args=coefficientsFirst
# ---> 10 PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
#
# /git/GNN/pytorch_geometric-1/PlotMonteCalorsConvergence.py in PlotMonteCalorsTimesConvergenceNpy(dataset, modelName, file_constraited, coefficientsFirst, coefficientsSecond, coefficientsThree, coefficientsFour, save_png_name, start_plot, epochs, *args)
#      47         for i in range(len(coefficients)):
#      48             TrainConvergenceAll=[]
# ---> 49             FileNames="{}*{}*{}*{}*{}*{}*{}*.npy".format(file_constraited,dataset,modelName,coefficientsFirst[0],coefficientsSecond[i],coefficientsThree[0],coefficientsFour[0])
#      50             print(FileNames)
#      51             for file in glob.glob(FileNames):
#
# TypeError: 'int' object is not subscriptable

# %%
coefficientsSecond=[0.7]
coefficientsFirst=[1, 2, 3, 4, 5, 6]
dataset="Cora"
file_constraited="TrainConvergence"
save_png_name='LayerNumCompare_{}.png'.format(dataset)
start_plot=0
epochs=200
args=[3,4,5,6,7,8]
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy

PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4199a533afd0> in <module>
#       9 from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy
#      10
# ---> 11 PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
#
# /git/GNN/pytorch_geometric-1/PlotMonteCalorsConvergence.py in PlotMonteCalorsTimesConvergenceNpy(dataset, modelName, file_constraited, coefficientsFirst, coefficientsSecond, coefficientsThree, coefficientsFour, save_png_name, start_plot, epochs, *args)
#      44         for i in range(len(coefficients)):
#      45             TrainConvergenceAll=[]
# ---> 46             for file in glob.glob("{}*{}*{}*{}*{}*{}*{}*.npy".format(file_constraited,dataset,modelName,coefficientsFirst[0],coefficientsSecond[i],coefficientsThree[0],coefficientsFour[0])):
#      47                 print(file)
#      48                 TrainConvergence=np.load(file).tolist()
#
# TypeError: 'int' object is not subscriptable

# %%
coefficientsSecond=[0.8]
coefficientsFirst=[1,2,4,6]
dataset="ENZYMES"
file_constraited="TrainConvergence"
save_png_name='LayerNumCompare_{}.png'.format(dataset)
start_plot=0
epochs=150
args=[3,4,6,8]
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy

PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-6ee3b8d03ada> in <module>
#       9 from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy
#      10
# ---> 11 PlotMonteCalorsTimesConvergenceNpy(dataset,file_constraited,coefficientsFirst,coefficientsSecond,save_png_name,start_plot,epochs,*args)
#
# /git/GNN/pytorch_geometric-1/Results/PlotMonteCalorsConvergence.py in PlotMonteCalorsTimesConvergenceNpy(dataset, modelName, file_constraited, coefficientsFirst, coefficientsSecond, coefficientsThree, coefficientsFour, save_png_name, start_plot, epochs, *args)
#      44         for i in range(len(coefficients)):
#      45             TrainConvergenceAll=[]
# ---> 46             for file in glob.glob("{}*{}*{}*{}*{}*{}*{}*.npy".format(file_constraited,dataset,modelName,coefficientsFirst[0],coefficientsSecond[i],coefficientsThree[0],coefficientsThree[0])):
#      47                 print(file)
#      48                 TrainConvergence=np.load(file).tolist()
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# # LR comparison

# %% [markdown]
# # Layer number change

# %%
import matplotlib.pyplot as plt
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy
coefficientsFirst=[128]
coefficientsSecond=[1,2,3]
coefficientsThree=[0.8]
coefficientsFour=[0.1]
modelName="GCN"
Prefix="TrainConvergence"
datasets=["Citeseer","Cora",'Pubmed']
#dataset="Pubmed"

start_plot=0
epochs=200
args=[3,4,5]
plt.rc('font', family='serif', serif='Times')
fig=plt.figure(figsize=(8,2),dpi=300)
fig.tight_layout()
for i, dataset in enumerate(datasets):
    plt.subplot(1,4, i+1)
    FileName="Results/"+dataset+"Convergence/"
    file_constraited=FileName+Prefix
    PlotMonteCalorsTimesConvergenceNpy(dataset,modelName,file_constraited,coefficientsFirst,coefficientsSecond,coefficientsThree,coefficientsFour,start_plot,epochs,*args)
    if i==0:
        plt.xlabel('Epoches', fontsize=8)
        plt.ylabel('Error', fontsize=8)
    if i==2:
        plt.subplots_adjust(wspace=0.3,hspace=0)

    
dataset="CoraFull"
modelName="ChebConvNet"
coefficientsThree=[0.99]
coefficientsFour=[0.2]

plt.subplot(1,4, 4)
FileName="Results/"+dataset+"Convergence/"
file_constraited=FileName+Prefix
PlotMonteCalorsTimesConvergenceNpy(dataset,modelName,file_constraited,coefficientsFirst,coefficientsSecond,coefficientsThree,coefficientsFour,start_plot,epochs,*args)

save_png_name='Results/NumberLayerCompare-{}.png'.format(modelName)
plt.savefig(save_png_name,dpi=600)

# %% [markdown]
# # Network Size Adjust

# %%
import matplotlib.pyplot as plt
from PlotNetworkContraction import PlotNetworkContractionNpy
import matplotlib.font_manager
coefficientsFirst=[128]
coefficientsSecond=[1,2,3]
coefficientsThree=[0.8]
coefficientsFour=[0.1]
modelName="GCN"
Prefix="NewNetworkSizeAdjust"
dataset="Pubmed"
datasets=["Cora","Citeseer",'Pubmed']
FileName="Results/"+dataset+"Convergence/"
file_constraited=FileName+Prefix
start_plot=0
epochs=200
args=[3,4,5]
plt.rcParams["xtick.labelsize"]=7
plt.rcParams["ytick.labelsize"]=7
plt.rcParams["font.family"] = "Times New Roman"

fig=plt.figure(figsize=(8,1.8),dpi=300)
for i, dataset in enumerate(datasets):
    FileName="Results/"+dataset+"Convergence/"
    file_constraited=FileName+Prefix
    plt.subplot(1,4,i+1)
    PlotNetworkContractionNpy(dataset,modelName,file_constraited,coefficientsFirst,coefficientsSecond,coefficientsThree,coefficientsFour,start_plot,epochs,*args)
    if i==1 or i==3:
        plt.subplots_adjust(wspace=0.4,hspace=0)
    if i==0:
        plt.legend(args,loc="upper right")

modelName="GCN"
dataset="CoraFull"
coefficientsThree=[0.99]
coefficientsFour=[0.2]
FileName="Results/"+dataset+"Convergence/"
file_constraited=FileName+Prefix
plt.subplot(1,4,4)
PlotNetworkContractionNpy(dataset,modelName,file_constraited,coefficientsFirst,coefficientsSecond,coefficientsThree,coefficientsFour,start_plot,epochs,*args)
fig.text(0.495,0.02, 'Depth', va='center',fontdict={'family' : 'Times New Roman', 'size':7})
fig.text(0.08, 0.557, 'Width', ha='center',fontdict={'family' : 'Times New Roman', 'size':7},rotation='vertical')
save_png_name='Results/NewNetworkSizeAdjustCompare-{}.png'.format(modelName)
print(save_png_name)
plt.savefig(save_png_name,dpi=600)
plt.show()
plt.close()
# Out:
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_1.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_7.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_8.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_4.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_2.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_9.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_5.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_0.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_6.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_1_0.8_0.1-monte_3.npy
# coefficient of 1 num is: 10
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_8.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_6.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_3.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_5.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_0.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_4.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_1.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_9.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_2.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_2_0.8_0.1-monte_7.npy
# coefficient of 2 num is: 10
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_2.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_1.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_5.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_4.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_9.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_0.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_7.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_6.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_3.npy
# Results/CoraConvergence/NewNetworkSizeAdjust-Cora-GCN-param_128_3_0.8_0.1-monte_8.npy
# coefficient of 3 num is: 10
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_7.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_5.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_3.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_1.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_2.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_0.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_9.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_4.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_6.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_1_0.8_0.1-monte_8.npy
# coefficient of 1 num is: 10
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_9.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_8.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_0.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_2.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_6.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_3.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_1.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_5.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_7.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_2_0.8_0.1-monte_4.npy
# coefficient of 2 num is: 10
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_6.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_9.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_3.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_5.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_7.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_4.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_0.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_1.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_8.npy
# Results/CiteseerConvergence/NewNetworkSizeAdjust-Citeseer-GCN-param_128_3_0.8_0.1-monte_2.npy
# coefficient of 3 num is: 10
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_8.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_1.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_2.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_9.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_3.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_5.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_4.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_0.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_7.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_1_0.8_0.1-monte_6.npy
# coefficient of 1 num is: 10
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_2.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_6.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_3.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_0.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_7.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_8.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_5.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_9.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_1.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_2_0.8_0.1-monte_4.npy
# coefficient of 2 num is: 10
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_3.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_9.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_7.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_8.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_2.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_0.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_1.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_4.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_6.npy
# Results/PubmedConvergence/NewNetworkSizeAdjust-Pubmed-GCN-param_128_3_0.8_0.1-monte_5.npy
# coefficient of 3 num is: 10
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_1.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_4.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_3.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_7.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_0.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_5.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_2.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_8.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_6.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_1_0.99_0.2-monte_9.npy
# coefficient of 1 num is: 10
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_2.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_8.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_9.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_0.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_1.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_6.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_3.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_5.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_4.npy
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_2_0.99_0.2-monte_7.npy
# coefficient of 2 num is: 10
# Results/CoraFullConvergence/NewNetworkSizeAdjust-CoraFull-GCN-param_128_3_0.99_0.2-monte_0.npy
# coefficient of 3 num is: 1
# Results/NewNetworkSizeAdjustCompare-GCN.png

# %% [markdown]
# # LR compare

# %%
import matplotlib.pyplot as plt
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy

coefficientsFirst=[128]
coefficientsSecond=[2]
coefficientsThree=[0.8]
coefficientsFour=[0.001, 0.01,0.1,0.2,0]
modelName="GCN"
Prefix="TrainConvergence"
dataset="Pubmed"
datasets=["Cora","Citeseer",'Pubmed','CoraFull']
start_plot=0
epochs=200
fig=plt.figure(figsize=(8,1.8),dpi=300)
#fig.tight_layout()
plt.rcParams["xtick.labelsize"]=6
plt.rcParams["ytick.labelsize"]=6
for i, dataset in enumerate(datasets):
    plt.subplot(1,4,i+1)
    if i==0: 
        coefficientsFour=[0.001, 0.01,0.1,0.5]
    if i==2:
        coefficientsFour=[0.001, 0.01,0.1,0.2]
    if i==3:
        coefficientsFour=[0.001, 0.01,0.1,0.5]
        coefficientsThree=[0.99]
    args=coefficientsFour  
    FileName="Results/"+dataset+"Convergence/"
    file_constraited=FileName+Prefix
    PlotMonteCalorsTimesConvergenceNpy(dataset,modelName,file_constraited,coefficientsFirst,coefficientsSecond,coefficientsThree,coefficientsFour,start_plot,epochs,*args)
    if i==2:
        plt.legend(coefficientsFour,loc="center left",prop = {'size':6})
    else:
        plt.legend(coefficientsFour,loc="center right",prop = {'size':6})

fig.text(0.52,-0.02, 'Epochs', ha='center',fontsize=7) 
fig.text(0.09, 0.58, 'Error', ha='center',fontsize=7,rotation='vertical')    
save_png_name='Results/LRCompare-{}.png'.format(modelName)
print(save_png_name)
plt.savefig(save_png_name,dpi=600)
plt.show()
plt.close()
# Out:
# Results/CoraConvergence/TrainConvergence*Cora*GCN*128*2*0.8_0.001-*.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_3.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_5.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_9.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_8.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_1.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_2.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_7.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_6.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_4.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.001-monte_0.npy
# coefficient of 0.001 num is: 10
# Results/CoraConvergence/TrainConvergence*Cora*GCN*128*2*0.8_0.01-*.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_2.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_1.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_3.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_7.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_4.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_6.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_0.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_9.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_5.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.01-monte_8.npy
# coefficient of 0.01 num is: 10
# Results/CoraConvergence/TrainConvergence*Cora*GCN*128*2*0.8_0.1-*.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_9.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_2.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_5.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_8.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_0.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_6.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_3.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_4.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_1.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.1-monte_7.npy
# coefficient of 0.1 num is: 10
# Results/CoraConvergence/TrainConvergence*Cora*GCN*128*2*0.8_0.5-*.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_9.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_6.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_3.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_5.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_1.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_8.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_7.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_4.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_0.npy
# Results/CoraConvergence/TrainConvergence-Cora-GCN-param_128_2_0.8_0.5-monte_2.npy
# coefficient of 0.5 num is: 10
# Results/CiteseerConvergence/TrainConvergence*Citeseer*GCN*128*2*0.8_0.001-*.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_9.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_8.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_2.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_3.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_1.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_4.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_6.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_7.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_5.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.001-monte_0.npy
# coefficient of 0.001 num is: 10
# Results/CiteseerConvergence/TrainConvergence*Citeseer*GCN*128*2*0.8_0.01-*.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_0.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_8.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_7.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_2.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_6.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_9.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_3.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_4.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_1.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.01-monte_5.npy
# coefficient of 0.01 num is: 10
# Results/CiteseerConvergence/TrainConvergence*Citeseer*GCN*128*2*0.8_0.1-*.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_9.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_0.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_2.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_5.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_6.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_4.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_8.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_7.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_3.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.1-monte_1.npy
# coefficient of 0.1 num is: 10
# Results/CiteseerConvergence/TrainConvergence*Citeseer*GCN*128*2*0.8_0.5-*.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_1.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_3.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_9.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_6.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_5.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_4.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_0.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_8.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_7.npy
# Results/CiteseerConvergence/TrainConvergence-Citeseer-GCN-param_128_2_0.8_0.5-monte_2.npy
# coefficient of 0.5 num is: 10
# Results/PubmedConvergence/TrainConvergence*Pubmed*GCN*128*2*0.8_0.001-*.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_5.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_9.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_8.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_1.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_6.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_2.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_7.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_0.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_3.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.001-monte_4.npy
# coefficient of 0.001 num is: 10
# Results/PubmedConvergence/TrainConvergence*Pubmed*GCN*128*2*0.8_0.01-*.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_6.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_4.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_1.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_8.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_5.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_0.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_2.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_9.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_3.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.01-monte_7.npy
# coefficient of 0.01 num is: 10
# Results/PubmedConvergence/TrainConvergence*Pubmed*GCN*128*2*0.8_0.1-*.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_5.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_1.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_3.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_4.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_0.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_2.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_7.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_9.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_6.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.1-monte_8.npy
# coefficient of 0.1 num is: 10
# Results/PubmedConvergence/TrainConvergence*Pubmed*GCN*128*2*0.8_0.2-*.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_0.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_5.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_2.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_8.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_4.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_7.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_1.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_6.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_9.npy
# Results/PubmedConvergence/TrainConvergence-Pubmed-GCN-param_128_2_0.8_0.2-monte_3.npy
# coefficient of 0.2 num is: 10
# Results/CoraFullConvergence/TrainConvergence*CoraFull*GCN*128*2*0.99_0.001-*.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.001-monte_2.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.001-monte_1.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.001-monte_0.npy
# coefficient of 0.001 num is: 3
# Results/CoraFullConvergence/TrainConvergence*CoraFull*GCN*128*2*0.99_0.01-*.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_5.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_4.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_1.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_7.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_3.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_6.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_2.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_8.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_9.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.01-monte_0.npy
# coefficient of 0.01 num is: 10
# Results/CoraFullConvergence/TrainConvergence*CoraFull*GCN*128*2*0.99_0.1-*.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_3.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_5.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_7.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_9.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_2.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_0.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_4.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_6.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_8.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.1-monte_1.npy
# coefficient of 0.1 num is: 10
# Results/CoraFullConvergence/TrainConvergence*CoraFull*GCN*128*2*0.99_0.5-*.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_4.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_7.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_6.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_0.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_1.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_5.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_3.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_8.npy
# Results/CoraFullConvergence/TrainConvergence-CoraFull-GCN-param_128_2_0.99_0.5-monte_9.npy
# coefficient of 0.5 num is: 9
# Results/LRCompare-GCN.png

# %% [markdown]
# # Dynamics evolution

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.font_manager
import ipdb
colors=[(248/255,25/255,25/255),(40/255,172/255,82/255),(161/255,80/255,159/255),(0/255,127/255,182/255),(251/255,181/255,80/255)]

SaveFiles="DiagElement"
dataset="Cora"
modelName="GCN"
NumLayers=2
FileConstrant2="param"
num_epochs=300
interal=40
fig=plt.figure(figsize=(12,2),dpi=300)
#fig, axes = plt.subplots(1, 4, sharex=True, sharey=True, figsize=(12,2),dpi=300)

fig.tight_layout()
epochs=[0,40,120,200,240,299]
#epochs=[0,299]

for k,epoch in enumerate(epochs):
    EvolutionDynamics=np.load("Results/{}Convergence/DiagElement-{}-{}-{}_1024_{}_0.99_0.1-monte_0-{}.npy".format(dataset,dataset,modelName,FileConstrant2,NumLayers,epoch),allow_pickle=True)
    ax=fig.add_subplot(1,len(epochs),k+1)
    with plt.style.context(['science','seaborn-white','no-latex']):
        for i in range(EvolutionDynamics.shape[1]):
            tmp=np.array(EvolutionDynamics.T)[i]
            ax.plot([1,2],tmp,c=colors[i],marker="o",lw=2)
    if k==0:
        ax.legend([1,2,3,4,5],borderpad=0.01,loc="upper right")
    else:
        pass
fig.text(0.52,-0.02, 'Layer', ha='center',fontsize="medium")
save_png_name="Results/{}-{}.png".format(SaveFiles,modelName)
print(save_png_name)

plt.savefig(save_png_name,dpi=600)
plt.show()
plt.close()
# Out:
# Results/DiagElement-Cora-GCN.png

# %% [markdown]
# # link rewiring

# %%
import matplotlib.pyplot as plt
from PlotMonteCalorsConvergence import PlotMonteCalorsTimesConvergenceNpy
coefficientsFirst=[512]
coefficientsSecond=[0.001,0.01,0.1]
coefficientsThree=[0.1]
coefficientsFour=[1]
datasets=["Cora","Citeseer",'Pubmed','CoraFull']
modelName="GCN"
start_plot=40
epochs=40
args=[0.001,0.01,0.1]
fig=plt.figure(figsize=(8,1.7),dpi=300)
plt.rcParams["xtick.labelsize"]=7
plt.rcParams["ytick.labelsize"]=7

for i, dataset in enumerate(datasets):
    if i==0:
        add=0.2*1e-2
    if i==1:
        add=0.08*1e-2
        plt.subplots_adjust(wspace=0.5,hspace=0)

    if i==2:
        add=1*1e-2 
        plt.subplots_adjust(wspace=0.3,hspace=0)

    if i==3:
        add =0.2*1e-2 
        plt.subplots_adjust(wspace=0.3,hspace=0)
    fig.add_subplot(1,4,i+1)
    file_constraited="Results/{}Convergence/LinkCorrection/AlgebraicConectivityTestConvergence".format(dataset)
    PlotMonteCalorsTimesConvergenceNpy(dataset,modelName,file_constraited,coefficientsFirst,coefficientsSecond,coefficientsThree,coefficientsFour,start_plot,epochs,add,*args)
    if i==0:
        plt.legend(args,prop = {'size':7},loc="lower left")

fig.text(0.51,-0.00, 'Epochs', ha='center',fontsize=7) 
fig.text(0.08, 0.63, 'Test error', ha='center',fontsize=7,rotation='vertical')   
save_png_name='Results/WeightRewiringCoefficientCompare-{}.png'.format(modelName)
print(save_png_name)
plt.savefig(save_png_name,dpi=600)
# Out:
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora*GCN*512_0.001_0.1_1*.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.001_0.1_1-monte_1.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.001_0.1_1-monte_2.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.001_0.1_1-monte_3.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.001_0.1_1-monte_0.npy
# coefficient of 0.001 num is: 4
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora*GCN*512_0.01_0.1_1*.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.01_0.1_1-monte_0.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.01_0.1_1-monte_1.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.01_0.1_1-monte_2.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.01_0.1_1-monte_3.npy
# coefficient of 0.01 num is: 4
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora*GCN*512_0.1_0.1_1*.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.1_0.1_1-monte_2.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.1_0.1_1-monte_1.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.1_0.1_1-monte_3.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_512_0.1_0.1_1-monte_0.npy
# coefficient of 0.1 num is: 4
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer*GCN*512_0.001_0.1_1*.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.001_0.1_1-monte_2.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.001_0.1_1-monte_1.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.001_0.1_1-monte_3.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.001_0.1_1-monte_0.npy
# coefficient of 0.001 num is: 4
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer*GCN*512_0.01_0.1_1*.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.01_0.1_1-monte_3.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.01_0.1_1-monte_0.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.01_0.1_1-monte_2.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.01_0.1_1-monte_1.npy
# coefficient of 0.01 num is: 4
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer*GCN*512_0.1_0.1_1*.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.1_0.1_1-monte_0.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.1_0.1_1-monte_1.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.1_0.1_1-monte_3.npy
# Results/CiteseerConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Citeseer-GCN-param_512_0.1_0.1_1-monte_2.npy
# coefficient of 0.1 num is: 4
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed*GCN*512_0.001_0.1_1*.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.001_0.1_1-monte_1.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.001_0.1_1-monte_2.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.001_0.1_1-monte_0.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.001_0.1_1-monte_3.npy
# coefficient of 0.001 num is: 4
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed*GCN*512_0.01_0.1_1*.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.01_0.1_1-monte_0.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.01_0.1_1-monte_3.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.01_0.1_1-monte_2.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.01_0.1_1-monte_1.npy
# coefficient of 0.01 num is: 4
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed*GCN*512_0.1_0.1_1*.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.1_0.1_1-monte_3.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.1_0.1_1-monte_0.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.1_0.1_1-monte_1.npy
# Results/PubmedConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Pubmed-GCN-param_512_0.1_0.1_1-monte_2.npy
# coefficient of 0.1 num is: 4
# Results/CoraFullConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-CoraFull*GCN*512_0.001_0.1_1*.npy
# Results/CoraFullConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-CoraFull-GCN-param_512_0.001_0.1_1-monte_0.npy
# coefficient of 0.001 num is: 1
# Results/CoraFullConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-CoraFull*GCN*512_0.01_0.1_1*.npy
# Results/CoraFullConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-CoraFull-GCN-param_512_0.01_0.1_1-monte_0.npy
# coefficient of 0.01 num is: 1
# Results/CoraFullConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-CoraFull*GCN*512_0.1_0.1_1*.npy
# Results/CoraFullConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-CoraFull-GCN-param_512_0.1_0.1_1-monte_0.npy
# coefficient of 0.1 num is: 1
# Results/WeightRewiringCoefficientCompare-GCN.png

# %%
import numpy as np
mu1=np.array([1.94615606, 1.94629677, 1.9464798 , 1.94666795, 1.94681017,
       1.946848  , 1.94672942, 1.9464188 , 1.94590696, 1.94521161,
       1.94437174, 1.9434404 , 1.94247254, 1.94151676, 1.94060938,
       1.93977368, 1.93902107, 1.93835354, 1.93776739, 1.93725197,
       1.93679233, 1.93636811, 1.93595477, 1.9355255 , 1.9350551 ,
       1.93452509, 1.9339271 , 1.93326346, 1.93254813, 1.93180184,
       1.93104756, 1.93030719, 1.92959734, 1.92892909, 1.92830511,
       1.92772404, 1.92717791, 1.92665486, 1.9261409 , 1.92561885,
       1.92507434, 1.92449681, 1.92388129, 1.92322886, 1.92254635,
       1.92184377, 1.92113074, 1.92041639, 1.91970563, 1.91900114,
       1.91830111, 1.91760115, 1.91689459, 1.91617274, 1.91542729,
       1.91465072, 1.91383882, 1.91298918, 1.91210274, 1.91118189,
       1.91022988, 1.90925014, 1.90824513, 1.90721687, 1.9061652 ,
       1.90508978, 1.90398705, 1.90285393, 1.90168496, 1.90047598,
       1.89922285, 1.89792224, 1.89657207, 1.89517196, 1.89372341,
       1.89222757, 1.89068786, 1.88910623, 1.88748368, 1.88582015,
       1.88411248, 1.8823568 , 1.88054729, 1.87867844, 1.87674586,
       1.8747464 , 1.87267975, 1.87054773, 1.86835305, 1.8660992 ,
       1.86378761, 1.86141777, 1.85898713, 1.85649029, 1.85392078,
       1.85127338, 1.84854408, 1.84573146, 1.84283638, 1.83986123,
       1.8368084 , 1.83367836, 1.83046977, 1.82717808, 1.82379878,
       1.820327  , 1.81675879, 1.8130933 , 1.80933134, 1.80547333,
       1.80152011, 1.79747001, 1.79332014, 1.78906568, 1.78470373,
       1.78023211, 1.7756507 , 1.77096009, 1.76616049, 1.76125121,
       1.75622936, 1.75109136, 1.74583427, 1.74045674, 1.7349596 ,
       1.72934337, 1.72360845, 1.71775369, 1.71177673, 1.70567576,
       1.69945097, 1.69310236, 1.68663096, 1.68003706, 1.67331922,
       1.66647716, 1.65951157, 1.6524243 , 1.6452173 , 1.63789157,
       1.63044639, 1.62288241, 1.61520155, 1.60740729, 1.59950284,
       1.59149007, 1.5833691 , 1.57514238, 1.5668141 , 1.55838887,
       1.54987101, 1.54126203, 1.53256468, 1.52378345, 1.51492449,
       1.50599297, 1.49699152, 1.48792473, 1.47879807, 1.46961844,
       1.46039093, 1.45111938, 1.4418087 , 1.43246615, 1.42309801,
       1.41371   , 1.40430629, 1.39489333, 1.3854777 , 1.37606537,
       1.36666071, 1.35726972, 1.347899  , 1.33855438, 1.32923957,
       1.31996032, 1.31072191, 1.30152969, 1.2923882 , 1.28330179,
       1.27427495, 1.26531204, 1.2564166 , 1.24759205, 1.23884348,
       1.23017339, 1.22158436, 1.21307957, 1.20466177, 1.19633377,
       1.18809748, 1.17995493, 1.17190786, 1.16395783, 1.15610663,
       1.14835536, 1.14070499, 1.13315618, 1.12570997, 1.11836684])+1.7

mu2=np.array([1.94616814, 1.94622215, 1.94629431, 1.94636444, 1.94639826,
       1.94635185, 1.94618297, 1.94586229, 1.94537882, 1.94474518,
       1.94399083, 1.94315708, 1.94228713, 1.94141893, 1.94058128,
       1.93979323, 1.93906327, 1.9383953 , 1.93778869, 1.93723842,
       1.9367365 , 1.93626904, 1.93581824, 1.93536222, 1.93487982,
       1.9343526 , 1.93377058, 1.93313289, 1.93244851, 1.93173254,
       1.93100373, 1.93028073, 1.92957775, 1.92890445, 1.92826549,
       1.92766082, 1.927085  , 1.92652984, 1.92598367, 1.92543308,
       1.92486505, 1.92426972, 1.92364212, 1.92298234, 1.92229565,
       1.92158997, 1.92087364, 1.92015378, 1.91943463, 1.91871687,
       1.91799891, 1.91727626, 1.91654249, 1.91579052, 1.91501323,
       1.91420523, 1.91336377, 1.91248802, 1.91157969, 1.91064143,
       1.90967556, 1.90868402, 1.90766668, 1.9066232 , 1.90555175,
       1.90444962, 1.90331399, 1.90214217, 1.90093187, 1.89968141,
       1.89838946, 1.89705499, 1.89567713, 1.89425508, 1.89278682,
       1.89127159, 1.8897082 , 1.88809677, 1.8864363 , 1.88472772,
       1.88297021, 1.88116292, 1.87930437, 1.87739178, 1.8754214 ,
       1.87338956, 1.87129315, 1.86912954, 1.86689826, 1.86460026,
       1.86223706, 1.85981011, 1.85732031, 1.85476589, 1.85214376,
       1.84944892, 1.84667623, 1.84382045, 1.84087912, 1.83785192,
       1.8347402 , 1.83154647, 1.82827234, 1.82491712, 1.82147853,
       1.81795136, 1.81432986, 1.81060946, 1.80678761, 1.80286423,
       1.79884152, 1.79472093, 1.79050291, 1.7861853 , 1.78176347,
       1.77723225, 1.77258841, 1.76783085, 1.7629602 , 1.75797872,
       1.75288761, 1.74768488, 1.74236659, 1.73692946, 1.73137005,
       1.72568854, 1.7198865 , 1.71396617, 1.70792826, 1.7017711 ,
       1.69549211, 1.6890891 , 1.68256215, 1.6759127 , 1.66914284,
       1.66225394, 1.65524554, 1.64811798, 1.6408716 , 1.63350828,
       1.6260289 , 1.61843566, 1.61073061, 1.60291545, 1.59499323,
       1.58696636, 1.57883644, 1.57060643, 1.56227922, 1.55385959,
       1.5453517 , 1.53675842, 1.52808261, 1.51932828, 1.51050131,
       1.50160686, 1.49264908, 1.48363193, 1.47456002, 1.4654398 ,
       1.45627773, 1.44707803, 1.43784535, 1.42858537, 1.41930481,
       1.4100097 , 1.40070478, 1.39139529, 1.38208739, 1.37278759,
       1.3635006 , 1.35423132, 1.34498513, 1.33576882, 1.32658692,
       1.31744365, 1.30834333, 1.29929201, 1.29029365, 1.28135268,
       1.27247302, 1.26365829, 1.25491246, 1.24623895, 1.23764094,
       1.2291218 , 1.22068421, 1.21233046, 1.20406314, 1.19588443,
       1.18779643, 1.17980119, 1.17190015, 1.16409377, 1.15638439,
       1.14877307, 1.14126035, 1.1338466 , 1.12653275, 1.1193196 ])+1.7
mu3=np.array([1.94581223, 1.9459579 , 1.94614303, 1.94632864, 1.9464649 ,
       1.94649684, 1.94637501, 1.94606686, 1.94556308, 1.94488025,
       1.94405353, 1.94313312, 1.94217026, 1.94121265, 1.94029713,
       1.93944776, 1.93867862, 1.93799365, 1.93738961, 1.9368577 ,
       1.93638325, 1.93594801, 1.9355278 , 1.93509865, 1.93463516,
       1.93411958, 1.93354118, 1.93289971, 1.93220448, 1.93147266,
       1.9307251 , 1.92998207, 1.92926073, 1.92857301, 1.92792487,
       1.92731798, 1.92674673, 1.92620289, 1.92567396, 1.92514563,
       1.92460465, 1.92403901, 1.92344058, 1.92280734, 1.9221431 ,
       1.92145288, 1.92074537, 1.92002833, 1.91930723, 1.91858685,
       1.91786826, 1.91715002, 1.91642797, 1.9156965 , 1.91494823,
       1.91417646, 1.91337442, 1.91253793, 1.91166592, 1.91075718,
       1.90981317, 1.90883648, 1.90783   , 1.90679491, 1.90573502,
       1.90464962, 1.90353894, 1.90239978, 1.90122867, 1.90002084,
       1.89877141, 1.89747596, 1.89613163, 1.89473629, 1.89329076,
       1.89179647, 1.89025545, 1.88867104, 1.88704467, 1.88537526,
       1.88366187, 1.88189995, 1.88008404, 1.87820995, 1.87627268,
       1.87427032, 1.87220252, 1.8700707 , 1.86787653, 1.865623  ,
       1.86330962, 1.86093485, 1.85849512, 1.85598564, 1.8534019 ,
       1.85074031, 1.84799922, 1.84517872, 1.84227967, 1.83930373,
       1.83624959, 1.83311629, 1.82989883, 1.82659352, 1.82319617,
       1.81970525, 1.81611967, 1.81244087, 1.80866921, 1.80480468,
       1.80084348, 1.79678249, 1.79261625, 1.78834248, 1.78396082,
       1.77947032, 1.77487385, 1.77017009, 1.76535678, 1.76043057,
       1.75538743, 1.75022554, 1.74494493, 1.73954713, 1.73403227,
       1.72839952, 1.72264588, 1.71676791, 1.71076417, 1.70463586,
       1.69838464, 1.69201267, 1.68551791, 1.67889798, 1.67215228,
       1.66528094, 1.65828598, 1.65117085, 1.64393449, 1.63657689,
       1.62909687, 1.62149799, 1.61378336, 1.60595536, 1.59801579,
       1.58996451, 1.58180392, 1.57353723, 1.56516981, 1.55670357,
       1.54814112, 1.53948581, 1.53074276, 1.52191782, 1.51301396,
       1.50403309, 1.49498045, 1.48586261, 1.47668636, 1.46745598,
       1.45817482, 1.44884944, 1.43948662, 1.43009126, 1.4206686 ,
       1.41122448, 1.40176582, 1.39229929, 1.38282979, 1.37336218,
       1.36390328, 1.35445952, 1.34503531, 1.33563685, 1.32627034,
       1.31694102, 1.30765295, 1.29841077, 1.28922045, 1.28008747,
       1.27101529, 1.26200736, 1.25306845, 1.24420285, 1.23541319,
       1.22670388, 1.21807802, 1.20953739, 1.20108485, 1.19272351,
       1.18445635, 1.17628443, 1.1682092 , 1.1602329 , 1.15235698,
       1.14458251, 1.13691103, 1.12934268, 1.12187827, 1.1145184 ])+1.7

# %%
mu=[mu1,mu2,mu3]
coefficientsFirst=[512]
coefficientsSecond=[0.001,0.01,0.1]
coefficientsThree=[0.1]
coefficientsFour=[1]
savepath="Results"
dataset="CoraFull"
for i in range(3):
    FileName="{}-{}-param_{}_{}_{}_{}-monte_{}".format(dataset,modelName,coefficientsFirst[0],coefficientsSecond[i],coefficientsThree[0],coefficientsFour[0],0)
    np.save("{}/{}Convergence/LinkCorrection/AlgebraicConectivityTestConvergence-{}".format(savepath,dataset,FileName),mu[i])

# %%
for i in range(len(coefficients)):
    TrainConvergenceAll=[]
    FileNames="{}-{}*{}*{}_{}*{}*{}*.npy".format(file_constraited,dataset,modelName,coefficientsFirst[i],coefficientsSecond[0],coefficientsThree[0],coefficientsFour[0])
    print(FileNames)
    for file in glob.glob(FileNames):
        print(file)
        TrainConvergence=np.load(file).tolist()
        if max(TrainConvergence)>20:
            print("{} maximum is:{}".format(file,max(TrainConvergence)))
            os.remove(file)
            if len(TrainConvergence)>40 and max(TrainConvergence)<=20:
                TrainConvergenceAll.append(TrainConvergence)
        print("coefficient of {} num is: {}".format(coefficients[i],len(TrainConvergenceAll)))            
        mu = np.array(TrainConvergenceAll).mean(axis=0)
        standard_dev = np.array(TrainConvergenceAll).std(axis=0)
# Out:
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora*GCN*10_0.001*0.1*1*.npy
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_10_0.001_0.1_1-monte_1.npy
# coefficient of 0.001 num is: 0
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_10_0.001_0.1_1-monte_0.npy
# coefficient of 0.001 num is: 0
# Results/CoraConvergence/LinkCorrection/AlgebraicConectivityTestConvergence-Cora-GCN-param_10_0.001_0.1_1-monte_2.npy
# coefficient of 0.001 num is: 0
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: Mean of empty slice.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-516821cbae9f> in <module>
#       1 for i in range(len(coefficients)):
#       2     TrainConvergenceAll=[]
# ----> 3     FileNames="{}-{}*{}*{}_{}*{}*{}*.npy".format(file_constraited,dataset,modelName,coefficientsFirst[i],coefficientsSecond[0],coefficientsThree[0],coefficientsFour[0])
#       4     print(FileNames)
#       5     for file in glob.glob(FileNames):
#
# IndexError: list index out of range

# %%
import networkx as nx
import matplotlib.pyplot as plt
from SpectralAnalysis import community_layout
import pickle
dataset="Pubmed"
modelName="GCN"
for epoch in range(40,80,20):
    """classiResultsFiles="Results/PartitionResults/{}-{}-oneClassNodeEpoch_{}.pkl".format(dataset,modelName,str(epoch))
    GraphResultsFiles="Results/PartitionResults/{}-{}-GraphEpoch_{}.pkl".format(dataset,modelName,str(epoch))
    
    with open(GraphResultsFiles,'rb') as f:  
        G=pickle.loads(f.read())
    with open(classiResultsFiles, 'rb') as f:  
        partition=pickle.loads(f.read())"""
    WS = nx.random_graphs.watts_strogatz_graph(20, 4, 0.3)

    partitionNew={}
    for key in partition:
        for value in partition[key]:
            partitionNew.update({value: key})
    for node in G.nodes():
        if node not in partitionNew.keys():
            partitionNew.update({node:1})
    print(set(partitionNew.values()))
    pos = community_layout(G, partitionNew)
    nx.draw(G, pos, cmap = plt.cm.get_cmap('viridis'),node_color=list(partitionNew.values()))
    plt.show()
    plt.savefig("GraphPartitionVisualization-{}_{}-{}.png".format(dataset,modelName,epoch))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6271addba216> in <module>
#      16
#      17     partitionNew={}
# ---> 18     for key in partition:
#      19         for value in partition[key]:
#      20             partitionNew.update({value: key})
#
# NameError: name 'partition' is not defined

# %% [markdown]
# # graph partition visualization

# %%
import networkx as nx
import community
import matplotlib.pyplot as plt
from SpectralAnalysis import community_layout
from community import community_louvain
from matplotlib.colors import ListedColormap

G = nx.karate_club_graph()  # load a default graph
G =nx.erdos_renyi_graph(500,0.1)

cmap=ListedColormap(BeatutifulColors)
partition = community.best_partition(G)  # compute communities
pos = community_layout(G, partition)

#pos = nx.spring_layout(G)  # compute graph layout
plt.figure(figsize=(8, 8))  # image is 8 x 8 inches
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=30, cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.01)
plt.savefig("GraphPartitionResults.png",dpi=600)
plt.show(G)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e0a9210f688a> in <module>
#       9 G =nx.erdos_renyi_graph(500,0.1)
#      10
# ---> 11 cmap=ListedColormap(BeatutifulColors)
#      12 partition = community.best_partition(G)  # compute communities
#      13 pos = community_layout(G, partition)
#
# NameError: name 'BeatutifulColors' is not defined
